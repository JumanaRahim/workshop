# %% [markdown]
# <a href="https://colab.research.google.com/github/JumanaRahim/workshop/blob/master/Lung%20cancer%20detection%201.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import tree
from sklearn.preprocessing import RobustScaler
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.feature_selection import mutual_info_classif
from sklearn.feature_selection import SelectKBest
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, f1_score
from sklearn.metrics import roc_auc_score

# %%
data=pd.read_csv("/content/thirddatasetdata1 (1).csv")

# %%
data.columns
# Out:
# Index(['ID', 'imaging.radiomics.GLCM_autocorr',
#        'imaging.radiomics.GLCM_clusProm', 'imaging.radiomics.GLCM_clusShade',
#        'imaging.radiomics.GLCM_clusTend', 'imaging.radiomics.GLCM_contrast',
#        'imaging.radiomics.GLCM_correl1', 'imaging.radiomics.GLCM_diffEntro',
#        'imaging.radiomics.GLCM_dissimilar', 'imaging.radiomics.GLCM_energy',
#        ...
#        'imaging.radiomics.Wavelet_LLL_stats_median',
#        'imaging.radiomics.Wavelet_LLL_stats_min',
#        'imaging.radiomics.Wavelet_LLL_stats_range',
#        'imaging.radiomics.Wavelet_LLL_stats_rms',
#        'imaging.radiomics.Wavelet_LLL_stats_skewness',
#        'imaging.radiomics.Wavelet_LLL_stats_std',
#        'imaging.radiomics.Wavelet_LLL_stats_totalenergy',
#        'imaging.radiomics.Wavelet_LLL_stats_uniformity',
#        'imaging.radiomics.Wavelet_LLL_stats_var', 'Label'],
#       dtype='object', length=638)

# %% [markdown]
# **DATA PREPROCESSING**

# %%
data_real = data.replace(np.inf, np.nan)

# %%
data_real.isnull().sum().sum()
# Out:
# 100

# %%
data_df = data_real.dropna(axis=0)

# %%
data_df.isnull().sum().sum()
# Out:
# 0

# %%
data_df
# Out:
#       ID  imaging.radiomics.GLCM_autocorr  imaging.radiomics.GLCM_clusProm  \
# 0      1                       453.182272                     104777.28120
# 1      2                       528.315776                       4260.94238
# 2      3                      1127.285945                     113572.19180
# 3      4                      1168.460376                      64098.28992
# 4      5                       714.993885                      42488.22647
# ..   ...                              ...                              ...
# 218  219                      1139.334792                      14516.60896
# 219  220                       818.698358                      87742.27268
# 220  221                       801.695540                      76994.34218
# 221  222                       341.806330                      29115.57843
# 222  223                       936.931162                     194689.94660
#
#      imaging.radiomics.GLCM_clusShade  imaging.radiomics.GLCM_clusTend  \
# 0                          674.017890                       222.638902
# 1                         -216.316062                        19.065842
# 2                        -1876.394931                       160.306058
# 3                        -1848.600663                        91.839214
# 4                        -1328.998406                        93.896236
# ..                                ...                              ...
# 218                        244.741173                        46.462792
# 219                      -2055.586897                       157.898761
# 220                      -2098.066288                       132.491348
# 221                       -784.954552                       101.804686
# 222                      -4100.072487                       204.343624
#
#      imaging.radiomics.GLCM_contrast  imaging.radiomics.GLCM_correl1  \
# 0                          27.372666                        0.781116
# 1                           5.393669                        0.612640
# 2                          35.961316                        0.630446
# 3                          17.133651                        0.682034
# 4                          20.667403                        0.632109
# ..                               ...                             ...
# 218                        16.106440                        0.482397
# 219                        23.252008                        0.742900
# 220                        18.352911                        0.753683
# 221                        19.284936                        0.702816
# 222                        14.641401                        0.868935
#
#      imaging.radiomics.GLCM_diffEntro  imaging.radiomics.GLCM_dissimilar  \
# 0                            2.392952                           4.064393
# 1                            1.524119                           1.302619
# 2                            2.435402                           3.931714
# 3                            1.988541                           2.409581
# 4                            2.188704                           2.960161
# ..                                ...                                ...
# 218                          1.983495                           2.391288
# 219                          2.265772                           3.303056
# 220                          2.121198                           2.716123
# 221                          2.202712                           3.313602
# 222                          2.107340                           2.738799
#
#      imaging.radiomics.GLCM_energy  ...  \
# 0                         0.002345  ...
# 1                         0.113870  ...
# 2                         0.008031  ...
# 3                         0.036164  ...
# 4                         0.030619  ...
# ..                             ...  ...
# 218                       0.022039  ...
# 219                       0.009143  ...
# 220                       0.020977  ...
# 221                       0.009943  ...
# 222                       0.010685  ...
#
#      imaging.radiomics.Wavelet_LLL_stats_median  \
# 0                                   1662.196015
# 1                                   2982.188746
# 2                                   2979.224981
# 3                                   2988.358359
# 4                                   2919.649317
# ..                                          ...
# 218                                 3055.887195
# 219                                 2797.141552
# 220                                 3052.583286
# 221                                 2565.730869
# 222                                 2789.375012
#
#      imaging.radiomics.Wavelet_LLL_stats_min  \
# 0                                 467.866888
# 1                                1371.523763
# 2                                 643.909824
# 3                                 711.386506
# 4                                1004.777916
# ..                                       ...
# 218                              1112.092053
# 219                               869.433409
# 220                              1007.135169
# 221                              1397.617681
# 222                               718.280510
#
#      imaging.radiomics.Wavelet_LLL_stats_range  \
# 0                                  2602.393670
# 1                                  1961.257947
# 2                                  3576.484800
# 3                                  3196.094809
# 4                                  2547.097206
# ..                                         ...
# 218                                3328.668697
# 219                                2899.659059
# 220                                2617.232001
# 221                                1740.429212
# 222                                2631.590236
#
#      imaging.radiomics.Wavelet_LLL_stats_rms  \
# 0                                1817.531872
# 1                                2905.312685
# 2                                2846.375865
# 3                                2832.966683
# 4                                2762.306176
# ..                                       ...
# 218                              3101.039311
# 219                              2699.092216
# 220                              2891.348422
# 221                              2515.580119
# 222                              2685.709214
#
#      imaging.radiomics.Wavelet_LLL_stats_skewness  \
# 0                                        0.289817
# 1                                       -2.215156
# 2                                       -0.924287
# 3                                       -1.833313
# 4                                       -1.157273
# ..                                            ...
# 218                                     -0.426993
# 219                                     -0.864501
# 220                                     -1.185849
# 221                                     -0.602095
# 222                                     -1.125448
#
#      imaging.radiomics.Wavelet_LLL_stats_std  \
# 0                                 558.438821
# 1                                 216.035768
# 2                                 522.757809
# 3                                 406.914394
# 4                                 443.861554
# ..                                       ...
# 218                               316.952421
# 219                               499.276162
# 220                               477.287930
# 221                               427.360059
# 222                               555.630581
#
#      imaging.radiomics.Wavelet_LLL_stats_totalenergy  \
# 0                                       1.676156e+10
# 1                                       3.254789e+10
# 2                                       7.111809e+10
# 3                                       2.640000e+11
# 4                                       2.112840e+10
# ..                                               ...
# 218                                     8.079737e+10
# 219                                     5.765427e+10
# 220                                     1.590000e+11
# 221                                     2.505945e+09
# 222                                     2.950131e+10
#
#      imaging.radiomics.Wavelet_LLL_stats_uniformity  \
# 0                                          0.035583
# 1                                          0.237286
# 2                                          0.057868
# 3                                          0.136353
# 4                                          0.099191
# ..                                              ...
# 218                                        0.111039
# 219                                        0.051432
# 220                                        0.074412
# 221                                        0.050645
# 222                                        0.051466
#
#      imaging.radiomics.Wavelet_LLL_stats_var     Label
# 0                               311853.91710     adeno
# 1                                46671.45319  squamous
# 2                               273275.72710     other
# 3                               165579.32370     adeno
# 4                               197013.07940     adeno
# ..                                       ...       ...
# 218                             100458.83710  squamous
# 219                             249276.68600  squamous
# 220                             227803.76820     adeno
# 221                             182636.61980     adeno
# 222                             308725.34260     adeno
#
# [222 rows x 638 columns]

# %% [markdown]
# **Unnamed:0, Unnamed:0.1 columns**

# %%
x = data_df.drop(['Label'], axis = 1)

# %%
x.columns
# Out:
# Index(['ID', 'imaging.radiomics.GLCM_autocorr',
#        'imaging.radiomics.GLCM_clusProm', 'imaging.radiomics.GLCM_clusShade',
#        'imaging.radiomics.GLCM_clusTend', 'imaging.radiomics.GLCM_contrast',
#        'imaging.radiomics.GLCM_correl1', 'imaging.radiomics.GLCM_diffEntro',
#        'imaging.radiomics.GLCM_dissimilar', 'imaging.radiomics.GLCM_energy',
#        ...
#        'imaging.radiomics.Wavelet_LLL_stats_mean',
#        'imaging.radiomics.Wavelet_LLL_stats_median',
#        'imaging.radiomics.Wavelet_LLL_stats_min',
#        'imaging.radiomics.Wavelet_LLL_stats_range',
#        'imaging.radiomics.Wavelet_LLL_stats_rms',
#        'imaging.radiomics.Wavelet_LLL_stats_skewness',
#        'imaging.radiomics.Wavelet_LLL_stats_std',
#        'imaging.radiomics.Wavelet_LLL_stats_totalenergy',
#        'imaging.radiomics.Wavelet_LLL_stats_uniformity',
#        'imaging.radiomics.Wavelet_LLL_stats_var'],
#       dtype='object', length=637)

# %%
data_df.isnull().sum().sum()
# Out:
# 0

# %%
y = data_df['Label']

# %% [markdown]
# **Label Encoding**

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()

# %%
y_trans = le.fit_transform(y)
le_fid = LabelEncoder()

# %% [markdown]
# **Train Test Split**

# %%
from sklearn.model_selection import train_test_split
X_train, X_test,y_train, y_test = train_test_split(x,y, train_size = 0.7)

# %% [markdown]
# **Standardization**

# %%
from sklearn.preprocessing import StandardScaler 
ss = StandardScaler()
X_train_std = ss.fit_transform(X_train)
X_test_std = ss.fit_transform(X_test)

# %% [markdown]
# Normalization

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
X_train_minmax = scaler.fit_transform(X_train)
X_test_minmax= scaler.fit_transform(X_test)

# %% [markdown]
# Feature Importance

# %%
from sklearn.feature_selection import mutual_info_classif
mutual_info = mutual_info_classif(X_train, y_train)
mutual_info = pd.Series(mutual_info)
mutual_info.index = X_train.columns
mutual_info.sort_values(ascending = False)
# Out:
# imaging.radiomics.Wavelet_HLH_rlgl_longRunEmphasis           0.138182
# imaging.radiomics.Wavelet_HHL_rlgl_grayLevelNonuniformity    0.129305
# imaging.radiomics.Wavelet_LLH_stats_uniformity               0.127242
# imaging.radiomics.Wavelet_HHH_glcm_contrast                  0.125778
# imaging.radiomics.Wavelet_LLH_stats_range                    0.120130
#                                                                ...
# imaging.radiomics.LoG_sigma_1_mm_3D_stats_uniformityPos      0.000000
# imaging.radiomics.Wavelet_HLL_glcm_maxProb                   0.000000
# imaging.radiomics.Wavelet_HLL_glcm_inverseVar                0.000000
# imaging.radiomics.Wavelet_HLL_glcm_invDiffnorm               0.000000
# imaging.radiomics.LoG_sigma_4_5_mm_3D_stats_entropyPos       0.000000
# Length: 637, dtype: float64

# %%
# visualize the feature importance
mutual_info.sort_values(ascending=False).plot.bar(figsize=(20,8))

# %% [markdown]
# Feature selection

# %%
from sklearn.feature_selection import SelectKBest
selector = SelectKBest(mutual_info_classif, k=5)
selector.fit(X_train, y_train)
cols = selector.get_support(indices=True)

# new dataframes
new_train = X_train.iloc[:,cols]
new_test = X_test.iloc[:,cols]

# %%
new_train
# Out:
#      imaging.radiomics.Wavelet_HHH_glcm_contrast  \
# 161                                    26.763197
# 158                                    19.918078
# 22                                     25.865227
# 7                                      18.959017
# 86                                     18.890011
# ..                                           ...
# 208                                    15.671159
# 54                                     36.293880
# 143                                    18.553900
# 43                                     26.973752
# 71                                     31.784539
#
#      imaging.radiomics.Wavelet_HHL_rlgl_grayLevelNonuniformity  \
# 161                                         209.274249
# 158                                       19020.962650
# 22                                         1322.409490
# 7                                           404.717406
# 86                                         2084.739512
# ..                                                 ...
# 208                                        3806.982537
# 54                                          179.429157
# 143                                         338.561217
# 43                                          537.727873
# 71                                          200.472042
#
#      imaging.radiomics.Wavelet_HLH_rlgl_longRunEmphasis  \
# 161                                           1.930189
# 158                                           2.404433
# 22                                            1.976065
# 7                                             1.512687
# 86                                            1.940229
# ..                                                 ...
# 208                                           3.354233
# 54                                            1.382573
# 143                                           1.476548
# 43                                            1.591773
# 71                                            1.678194
#
#      imaging.radiomics.Wavelet_LLH_stats_range  \
# 161                                 637.573093
# 158                                 947.753027
# 22                                  709.673816
# 7                                   501.782577
# 86                                  643.978292
# ..                                         ...
# 208                                1346.697392
# 54                                  696.564629
# 143                                 767.982145
# 43                                  811.556905
# 71                                  591.787240
#
#      imaging.radiomics.Wavelet_LLH_stats_uniformity
# 161                                        0.064901
# 158                                        0.154466
# 22                                         0.122436
# 7                                          0.069982
# 86                                         0.087506
# ..                                              ...
# 208                                        0.174699
# 54                                         0.049897
# 143                                        0.096082
# 43                                         0.075485
# 71                                         0.096135
#
# [155 rows x 5 columns]

# %% [markdown]
# Model Training
# 1. Decision-tree

# %%
dt = DecisionTreeClassifier(criterion='entropy', max_depth=None,min_samples_split=2, max_leaf_nodes=None)
dt.fit(new_train, y_train)
test_pred = dt.predict(new_test)

# %%
Y_predicted_dt = dt.predict(new_test)
Y_pred_train_dt = dt.predict(new_train)

# %%
print('\n Confusion Matrix \n')
print(confusion_matrix(Y_predicted_dt, y_test))

ac = accuracy_score(y_test, Y_predicted_dt)
print('\n Macro Averaged Accuracy :'+str(ac))

pr = precision_score(y_test, Y_predicted_dt, average='macro')
print('\n Macro Averaged Precision :'+str(pr))

re = recall_score(y_test, Y_predicted_dt, average='macro')
print('\n Macro Averaged Recall :'+str(re))

fm = f1_score(y_test, Y_predicted_dt, average='macro')
print('\n Macro Averaged F1-Score :'+str(fm))

fm = f1_score(y_train, Y_pred_train_dt, average='macro')
print('\n Macro Averaged F1-Score on training :'+str(fm))

fm = f1_score(y_test, Y_predicted_dt, average='micro')
print('\n Micro Averaged F1-Score:'+str(fm))
# Out:
#  Confusion Matrix
#
# [[22  7 13]
#  [ 7  3  2]
#  [ 5  2  6]]
#
#  Macro Averaged Accuracy :0.4626865671641791
#
#  Macro Averaged Precision :0.4117826617826618
#
#  Macro Averaged Recall :0.3942577030812325
#
#  Macro Averaged F1-Score :0.3939628482972137
#
#  Macro Averaged F1-Score on training :1.0
#
#  Micro Averaged F1-Score:0.4626865671641791

# %%
plt.figure(figsize=(25, 10))
tree.plot_tree(dt, filled=True)
# Out:
# [Text(0.39961816720257237, 0.9722222222222222, 'X[2] <= 1.523\nentropy = 1.346\nsamples = 155\nvalue = [93, 22, 40]'),
#  Text(0.15514469453376206, 0.9166666666666666, 'X[1] <= 145.094\nentropy = 0.84\nsamples = 26\nvalue = [19, 7, 0]'),
#  Text(0.10369774919614148, 0.8611111111111112, 'X[1] <= 37.481\nentropy = 0.971\nsamples = 10\nvalue = [4, 6, 0]'),
#  Text(0.07797427652733119, 0.8055555555555556, 'entropy = 0.0\nsamples = 3\nvalue = [3, 0, 0]'),
#  Text(0.12942122186495178, 0.8055555555555556, 'X[0] <= 20.126\nentropy = 0.592\nsamples = 7\nvalue = [1, 6, 0]'),
#  Text(0.10369774919614148, 0.75, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0, 0]'),
#  Text(0.15514469453376206, 0.75, 'entropy = 0.0\nsamples = 6\nvalue = [0, 6, 0]'),
#  Text(0.20659163987138263, 0.8611111111111112, 'X[2] <= 1.515\nentropy = 0.337\nsamples = 16\nvalue = [15, 1, 0]'),
#  Text(0.18086816720257234, 0.8055555555555556, 'entropy = 0.0\nsamples = 15\nvalue = [15, 0, 0]'),
#  Text(0.23231511254019294, 0.8055555555555556, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(0.6440916398713826, 0.9166666666666666, 'X[4] <= 0.175\nentropy = 1.345\nsamples = 129\nvalue = [74, 15, 40]'),
#  Text(0.45538585209003213, 0.8611111111111112, 'X[1] <= 2085.719\nentropy = 1.204\nsamples = 104\nvalue = [63, 6, 35]'),
#  Text(0.2837620578778135, 0.8055555555555556, 'X[1] <= 1429.662\nentropy = 1.166\nsamples = 82\nvalue = [55, 6, 21]'),
#  Text(0.2580385852090032, 0.75, 'X[3] <= 526.887\nentropy = 1.249\nsamples = 71\nvalue = [44, 6, 21]'),
#  Text(0.17363344051446947, 0.6944444444444444, 'X[2] <= 1.559\nentropy = 0.414\nsamples = 12\nvalue = [11, 1, 0]'),
#  Text(0.14790996784565916, 0.6388888888888888, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(0.19935691318327975, 0.6388888888888888, 'entropy = 0.0\nsamples = 11\nvalue = [11, 0, 0]'),
#  Text(0.342443729903537, 0.6944444444444444, 'X[3] <= 565.816\nentropy = 1.301\nsamples = 59\nvalue = [33, 5, 21]'),
#  Text(0.2508038585209003, 0.6388888888888888, 'X[0] <= 20.563\nentropy = 0.811\nsamples = 8\nvalue = [2, 0, 6]'),
#  Text(0.22508038585209003, 0.5833333333333334, 'entropy = 0.0\nsamples = 6\nvalue = [0, 0, 6]'),
#  Text(0.2765273311897106, 0.5833333333333334, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0, 0]'),
#  Text(0.4340836012861736, 0.6388888888888888, 'X[2] <= 2.27\nentropy = 1.284\nsamples = 51\nvalue = [31, 5, 15]'),
#  Text(0.3279742765273312, 0.5833333333333334, 'X[2] <= 1.821\nentropy = 1.307\nsamples = 44\nvalue = [25, 4, 15]'),
#  Text(0.24437299035369775, 0.5277777777777778, 'X[4] <= 0.121\nentropy = 1.253\nsamples = 32\nvalue = [21, 4, 7]'),
#  Text(0.21864951768488747, 0.4722222222222222, 'X[3] <= 954.416\nentropy = 1.179\nsamples = 30\nvalue = [21, 4, 5]'),
#  Text(0.12861736334405144, 0.4166666666666667, 'X[2] <= 1.744\nentropy = 0.974\nsamples = 24\nvalue = [18, 1, 5]'),
#  Text(0.07717041800643087, 0.3611111111111111, 'X[0] <= 31.706\nentropy = 0.831\nsamples = 19\nvalue = [14, 0, 5]'),
#  Text(0.05144694533762058, 0.3055555555555556, 'X[1] <= 405.986\nentropy = 0.764\nsamples = 18\nvalue = [14, 0, 4]'),
#  Text(0.02572347266881029, 0.25, 'entropy = 0.0\nsamples = 7\nvalue = [7, 0, 0]'),
#  Text(0.07717041800643087, 0.25, 'X[1] <= 847.668\nentropy = 0.946\nsamples = 11\nvalue = [7, 0, 4]'),
#  Text(0.05144694533762058, 0.19444444444444445, 'X[2] <= 1.592\nentropy = 0.985\nsamples = 7\nvalue = [3, 0, 4]'),
#  Text(0.02572347266881029, 0.1388888888888889, 'entropy = 0.0\nsamples = 2\nvalue = [0, 0, 2]'),
#  Text(0.07717041800643087, 0.1388888888888889, 'X[0] <= 18.072\nentropy = 0.971\nsamples = 5\nvalue = [3, 0, 2]'),
#  Text(0.05144694533762058, 0.08333333333333333, 'X[2] <= 1.655\nentropy = 0.918\nsamples = 3\nvalue = [1, 0, 2]'),
#  Text(0.02572347266881029, 0.027777777777777776, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0, 0]'),
#  Text(0.07717041800643087, 0.027777777777777776, 'entropy = 0.0\nsamples = 2\nvalue = [0, 0, 2]'),
#  Text(0.10289389067524116, 0.08333333333333333, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0, 0]'),
#  Text(0.10289389067524116, 0.19444444444444445, 'entropy = 0.0\nsamples = 4\nvalue = [4, 0, 0]'),
#  Text(0.10289389067524116, 0.3055555555555556, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.18006430868167203, 0.3611111111111111, 'X[0] <= 16.157\nentropy = 0.722\nsamples = 5\nvalue = [4, 1, 0]'),
#  Text(0.15434083601286175, 0.3055555555555556, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(0.2057877813504823, 0.3055555555555556, 'entropy = 0.0\nsamples = 4\nvalue = [4, 0, 0]'),
#  Text(0.3086816720257235, 0.4166666666666667, 'X[4] <= 0.102\nentropy = 1.0\nsamples = 6\nvalue = [3, 3, 0]'),
#  Text(0.2829581993569132, 0.3611111111111111, 'X[2] <= 1.556\nentropy = 0.811\nsamples = 4\nvalue = [1, 3, 0]'),
#  Text(0.2572347266881029, 0.3055555555555556, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0, 0]'),
#  Text(0.3086816720257235, 0.3055555555555556, 'entropy = 0.0\nsamples = 3\nvalue = [0, 3, 0]'),
#  Text(0.33440514469453375, 0.3611111111111111, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0, 0]'),
#  Text(0.27009646302250806, 0.4722222222222222, 'entropy = 0.0\nsamples = 2\nvalue = [0, 0, 2]'),
#  Text(0.4115755627009646, 0.5277777777777778, 'X[0] <= 16.644\nentropy = 0.918\nsamples = 12\nvalue = [4, 0, 8]'),
#  Text(0.3858520900321543, 0.4722222222222222, 'X[2] <= 2.045\nentropy = 0.985\nsamples = 7\nvalue = [4, 0, 3]'),
#  Text(0.36012861736334406, 0.4166666666666667, 'entropy = 0.0\nsamples = 3\nvalue = [3, 0, 0]'),
#  Text(0.4115755627009646, 0.4166666666666667, 'X[3] <= 683.491\nentropy = 0.811\nsamples = 4\nvalue = [1, 0, 3]'),
#  Text(0.3858520900321543, 0.3611111111111111, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0, 0]'),
#  Text(0.43729903536977494, 0.3611111111111111, 'entropy = 0.0\nsamples = 3\nvalue = [0, 0, 3]'),
#  Text(0.43729903536977494, 0.4722222222222222, 'entropy = 0.0\nsamples = 5\nvalue = [0, 0, 5]'),
#  Text(0.5401929260450161, 0.5833333333333334, 'X[3] <= 742.071\nentropy = 0.592\nsamples = 7\nvalue = [6, 1, 0]'),
#  Text(0.5144694533762058, 0.5277777777777778, 'X[2] <= 3.024\nentropy = 1.0\nsamples = 2\nvalue = [1, 1, 0]'),
#  Text(0.4887459807073955, 0.4722222222222222, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(0.5401929260450161, 0.4722222222222222, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0, 0]'),
#  Text(0.5659163987138264, 0.5277777777777778, 'entropy = 0.0\nsamples = 5\nvalue = [5, 0, 0]'),
#  Text(0.3094855305466238, 0.75, 'entropy = 0.0\nsamples = 11\nvalue = [11, 0, 0]'),
#  Text(0.6270096463022508, 0.8055555555555556, 'X[3] <= 1102.009\nentropy = 0.946\nsamples = 22\nvalue = [8, 0, 14]'),
#  Text(0.5627009646302251, 0.75, 'X[0] <= 13.731\nentropy = 0.996\nsamples = 13\nvalue = [7, 0, 6]'),
#  Text(0.5112540192926045, 0.6944444444444444, 'X[1] <= 6801.491\nentropy = 0.65\nsamples = 6\nvalue = [5, 0, 1]'),
#  Text(0.4855305466237942, 0.6388888888888888, 'entropy = 0.0\nsamples = 5\nvalue = [5, 0, 0]'),
#  Text(0.5369774919614148, 0.6388888888888888, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.6141479099678456, 0.6944444444444444, 'X[0] <= 18.946\nentropy = 0.863\nsamples = 7\nvalue = [2, 0, 5]'),
#  Text(0.5884244372990354, 0.6388888888888888, 'entropy = 0.0\nsamples = 4\nvalue = [0, 0, 4]'),
#  Text(0.639871382636656, 0.6388888888888888, 'X[3] <= 917.243\nentropy = 0.918\nsamples = 3\nvalue = [2, 0, 1]'),
#  Text(0.6141479099678456, 0.5833333333333334, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.6655948553054662, 0.5833333333333334, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0, 0]'),
#  Text(0.6913183279742765, 0.75, 'X[4] <= 0.103\nentropy = 0.503\nsamples = 9\nvalue = [1, 0, 8]'),
#  Text(0.6655948553054662, 0.6944444444444444, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0, 0]'),
#  Text(0.7170418006430869, 0.6944444444444444, 'entropy = 0.0\nsamples = 8\nvalue = [0, 0, 8]'),
#  Text(0.8327974276527331, 0.8611111111111112, 'X[4] <= 0.188\nentropy = 1.516\nsamples = 25\nvalue = [11, 9, 5]'),
#  Text(0.7684887459807074, 0.8055555555555556, 'X[2] <= 2.33\nentropy = 0.918\nsamples = 6\nvalue = [0, 4, 2]'),
#  Text(0.7427652733118971, 0.75, 'entropy = 0.0\nsamples = 2\nvalue = [0, 0, 2]'),
#  Text(0.7942122186495176, 0.75, 'entropy = 0.0\nsamples = 4\nvalue = [0, 4, 0]'),
#  Text(0.8971061093247589, 0.8055555555555556, 'X[3] <= 1071.153\nentropy = 1.384\nsamples = 19\nvalue = [11, 5, 3]'),
#  Text(0.8456591639871383, 0.75, 'X[4] <= 0.244\nentropy = 1.0\nsamples = 8\nvalue = [4, 4, 0]'),
#  Text(0.819935691318328, 0.6944444444444444, 'X[2] <= 3.1\nentropy = 0.722\nsamples = 5\nvalue = [4, 1, 0]'),
#  Text(0.7942122186495176, 0.6388888888888888, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(0.8456591639871383, 0.6388888888888888, 'entropy = 0.0\nsamples = 4\nvalue = [4, 0, 0]'),
#  Text(0.8713826366559485, 0.6944444444444444, 'entropy = 0.0\nsamples = 3\nvalue = [0, 3, 0]'),
#  Text(0.9485530546623794, 0.75, 'X[2] <= 6.209\nentropy = 1.241\nsamples = 11\nvalue = [7, 1, 3]'),
#  Text(0.9228295819935691, 0.6944444444444444, 'X[3] <= 1194.079\nentropy = 0.881\nsamples = 10\nvalue = [7, 0, 3]'),
#  Text(0.8971061093247589, 0.6388888888888888, 'X[1] <= 5368.428\nentropy = 1.0\nsamples = 6\nvalue = [3, 0, 3]'),
#  Text(0.8713826366559485, 0.5833333333333334, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0, 0]'),
#  Text(0.9228295819935691, 0.5833333333333334, 'X[3] <= 1115.32\nentropy = 0.811\nsamples = 4\nvalue = [1, 0, 3]'),
#  Text(0.8971061093247589, 0.5277777777777778, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0, 0]'),
#  Text(0.9485530546623794, 0.5277777777777778, 'entropy = 0.0\nsamples = 3\nvalue = [0, 0, 3]'),
#  Text(0.9485530546623794, 0.6388888888888888, 'entropy = 0.0\nsamples = 4\nvalue = [4, 0, 0]'),
#  Text(0.9742765273311897, 0.6944444444444444, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1, 0]')]

# %%
# AUC ROC scores on the training and test dataset
from sklearn.multiclass import OneVsRestClassifier
AUC_ROC_Score = roc_auc_score(y_train, dt.predict_proba(new_train),multi_class='ovr')
print("On training data, DT has a AUCROC Score of:", AUC_ROC_Score * 100)

AUC_ROC_Score = roc_auc_score(y_test, dt.predict_proba(new_test),multi_class='ovr')
print("On test data, DT has a AUCROC Score of:", AUC_ROC_Score * 100)
# Out:
# On training data, DT has a AUCROC Score of: 100.0
# On test data, DT has a AUCROC Score of: 63.951854708433665

# %% [markdown]
# 2. Random forest

# %%
rf = RandomForestClassifier(n_estimators=100, criterion='entropy', max_depth=None)
rf = rf.fit(new_train, y_train)
Y_predicted_rf = rf.predict(new_test)
Y_pred_train_rf = rf.predict(new_train)

# %%
print('\n Confusion Matrix \n')
print(confusion_matrix(Y_predicted_rf, y_test))

ac = accuracy_score(y_test, Y_predicted_rf)
print('\n Macro Averaged Accuracy :'+str(ac))

pr = precision_score(y_test, Y_predicted_rf, average='macro')
print('\n Macro Averaged Precision :'+str(pr))

re = recall_score(y_test, Y_predicted_rf, average='macro')
print('\n Macro Averaged Recall :'+str(re))

fm = f1_score(y_test, Y_predicted_rf, average='macro')
print('\n Macro Averaged F1-Score :'+str(fm))

fm = f1_score(y_test, Y_predicted_rf, average='micro')
print('\n Micro Averaged F1-Score:'+str(fm))
# Out:
#  Confusion Matrix
#
# [[29  8 17]
#  [ 3  2  0]
#  [ 2  2  4]]
#
#  Macro Averaged Accuracy :0.5223880597014925
#
#  Macro Averaged Precision :0.47901234567901235
#
#  Macro Averaged Recall :0.4033613445378151
#
#  Macro Averaged F1-Score :0.39008236523449497
#
#  Micro Averaged F1-Score:0.5223880597014925

# %% [markdown]
# 3. XG Boost

# %%
from sklearn.ensemble import GradientBoostingClassifier

# %%
gradient_boost = GradientBoostingClassifier()
gb = gb.fit(X_train, y_train)

# %%
Y_predicted_gb = gb.predict(X_test)
Y_pred_train_gb = gb.predict(X_train)

# %%
print('\n Confusion Matrix \n')
print(confusion_matrix(Y_predicted_gb, y_test))

ac = accuracy_score(y_test, Y_predicted_gb)
print('\n Macro Averaged Accuracy :'+str(ac))

pr = precision_score(y_test, Y_predicted_gb, average='macro')
print('\n Macro Averaged Precision :'+str(pr))

re = recall_score(y_test,Y_predicted_gb, average='macro')
print('\n Macro Averaged Recall :'+str(re))

fm = f1_score(y_test, Y_predicted_gb, average='macro')
print('\n Macro Averaged F1-Score :'+str(fm))

fm = f1_score(y_test,Y_predicted_gb, average='micro')
print('\n Micro Averaged F1-Score:'+str(fm))
# Out:
#  Confusion Matrix
#
# [[25  7 15]
#  [ 4  1  2]
#  [ 5  4  4]]
#
#  Macro Averaged Accuracy :0.44776119402985076
#
#  Macro Averaged Precision :0.3274881147221573
#
#  Macro Averaged Recall :0.3363678804855275
#
#  Macro Averaged F1-Score :0.3192804087196932
#
#  Micro Averaged F1-Score:0.44776119402985076

# %% [markdown]
# 4. Logistic Regression

# %%
logres=LogisticRegression(solver='liblinear')
logres.fit(new_train, y_train)
Y_predicted_logres = logres.predict(new_test)
Y_pred_train_logres = logres.predict(new_train)

# %%
print('\n Confusion Matrix \n')
print(confusion_matrix(Y_predicted_logres, y_test))

ac = accuracy_score(y_test, Y_predicted_logres)
print('\n Macro Averaged Accuracy :'+str(ac))

pr = precision_score(y_test, Y_predicted_logres, average='macro')
print('\n Macro Averaged Precision :'+str(pr))

re = recall_score(y_test, Y_predicted_logres, average='macro')
print('\n Macro Averaged Recall :'+str(re))

fm = f1_score(y_test, Y_predicted_logres, average='macro')
print('\n Macro Averaged F1-Score :'+str(fm))

fm = f1_score(y_test, Y_predicted_logres, average='micro')
print('\n Micro Averaged F1-Score:'+str(fm))
# Out:
#  Confusion Matrix
#
# [[34 11 18]
#  [ 0  0  0]
#  [ 0  1  3]]
#
#  Macro Averaged Accuracy :0.5522388059701493
#
#  Macro Averaged Precision :0.42989417989417983
#
#  Macro Averaged Recall :0.38095238095238093
#
#  Macro Averaged F1-Score :0.3136769759450172
#
#  Micro Averaged F1-Score:0.5522388059701493
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
